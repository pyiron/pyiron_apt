# %% [markdown]
# <table table style='table-layout:fixed;width:100%' border="0">
#   <th style='width: 65%;'> </th>
# <tr>
#   <td>
#     <font style="font-family:roboto;color:#455e6c;font-size:26px;text-align:justify"> <b> IUC09: Infrastructure interfaces with condensed matter physics <br><br> </b> </font>
#     <font style="font-family:roboto;color:#455e6c;font-size:14px;text-align:justify"> Markus Kühbach </font> <br>
#     <font style="font-family:roboto;color:#455e6c;font-size:12px;text-align:justify"> Humboldt-Universität zu Berlin<br><br></font>
#     <font style="font-family:roboto;color:#455e6c;font-size:14px;text-align:justify"> Sarath Menon, Alaukik Saxena, Tilmann Hickel <br> </font>
#     <font style="font-family:roboto;color:#455e6c;font-size:12px;text-align:justify"> Max-Planck-Institut für Eisenforschung GmbH <br><br></font>
#     <font style="font-family:roboto;color:#455e6c;font-size:14px;text-align:justify"> Mariano Forti, Thomas Hammerschmidt </font> <br>
#     <font style="font-family:roboto;color:#455e6c;font-size:12px;text-align:justify"> Ruhr-Universität Bochum <br></font>
#
#   <td>
#     <img src="iuc09.png" width="100%" align="right"></td>
# </tr>
# </table>
#
# Atom probe tomography (APT) and related field-ion microscopy became mature nanoscale structure and composition characterization methods: A technique to gain a more detailed understanding of microstructure-materials-properties relations and a rich collection of distributed point-cloud datasets for developing new and improving existent data-analysis techniques. There are several possibilities for improving the current state-of-the-art in terms of how software for analyzing atom probe data gets developed, how such software is being used, and how we can support scientists who would like to share datasets and results more frequently between laboratories. This demonstrator delivers an update on the progress within a cooperation between the NFDI-MatWerk and FAIRmat consortia on coupling different tools for analyzing atom probe data and showing their interoperability. We will focus on an example of characterizing composition and structural features of interfaces in an engineering alloy.

# %% [markdown]
# <font style="font-family:roboto;color:#455e6c;font-size:18px;text-align:justify"> <b> Contents <br> </b> </font>

# %% [markdown]
# - [Download datasets for analysis](01_download_data.ipynb)
# - [APT analysis workflow using CompositionSpace in combination with pyiron](02_workflow_compositionspace.ipynb)
# - [APT analysis workflow using Paraprobe-toolbox in combination with pyiron](03_workflow_paraprobe.ipynb)
# - [APT analysis workflow which illustrates interoperability between the two tools](04_mixed_workflow.ipynb)

# %% [markdown]
# <font style="font-family:roboto;color:#455e6c;font-size:18px;text-align:justify"> <b> Further resources <br> </b> </font>

# %% [markdown]
# - [Paraprobe repository](https://gitlab.com/paraprobe/paraprobe-toolbox)
# - [CompositionSpace repository](https://github.com/eisenforschung/CompositionSpace)
# - [pyiron webpage](https://pyiron.org/)
# - [learn more about pyiron](http://pyiron.org/potentials-workshop-2022/intro.html)

# %% [markdown]
# <font style="font-family:roboto;color:#455e6c;font-size:18px;text-align:justify"> <b> Acknowledgements <br> </b> </font>
#
# This work is supported by the [NFDI-Matwerk](https://nfdi-matwerk.de/) consortia. In addition, we acknowledge [FAIRmat](https://www.fair-di.eu/fairmat/about-fairmat/consortium-fairmat). FAIRmat is a consortium on research data management which is part of the [German NFDI](https://www.nfdi.de/?lang=en). The project is funded by the Deutsche Forschungsgemeinschaft (DFG, German Research Foundation) – project 460197019.

# %% [markdown]
# <table table style='table-layout:fixed;width:50%' border="0">
#   <th style='width: 50%;'> </th>
# <tr>
#   <td>
#     <img src="Logo_NFDI-MatWerk.png" width="50%" align="right"></td>
#   <td>
#     <img src="NOMADOasisLogo.png" width="50%" align="right"></td>
# </tr>
# </table>
